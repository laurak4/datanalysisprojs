# %% [markdown]
# # Assignment 2 - Team 9

# %% [markdown]
# ##  Austin Nguyen and Laura Kay

# %%
Required Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ### Part A) Regression: Using New Data Set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Read the data
data = pd.read_csv('data/auto-mpg.csv')

#replace NAN with mean value for mpg and acceleration
data['mpg'].fillna(data['mpg'].mean(), inplace=True)
data['acceleration'].fillna(data['acceleration'].mean(), inplace=True)


# Choose X and Y variables
x = data[['mpg']]
y = data['acceleration']

# Split to training and test 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

regr = LinearRegression()

regr.fit(x_train, y_train)

# predictions training and test data
y_train_pred = regr.predict(x_train)
y_test_pred = regr.predict(x_test)


# training data plot
plt.figure(figsize=(10, 6))
plt.scatter(x_train, y_train, color='black', label='Training Data')
plt.plot(x_train, y_train_pred, color='blue', linewidth=2, label='Regression Line')
plt.xlabel('mpg')
plt.ylabel('acceleration')
plt.title('Simple Linear Regression - Training Data')
plt.show()

# test data plot
plt.figure(figsize=(10, 6))
plt.scatter(x_test, y_test, color='black', label='Test Data')
plt.plot(x_test, y_test_pred, color='blue', linewidth=2, label='Regression Line')
plt.xlabel('mpg')
plt.ylabel('acceleration')
plt.title('Simple Linear Regression - Test Data')
plt.show()

# %% [markdown]
# ### Part A Multiple Regression

# %% [markdown]
# Step 1: Split Input Data into Training and Test Sets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Read the data
data = pd.read_csv('data/auto-mpg.csv')
#replace nan with mean value 
data['mpg'].fillna(data['mpg'].mean(), inplace=True)
data['displacement'].fillna(data['displacement'].mean(), inplace=True)

# Choose X and Y variables
x = data[['displacement']]
y = data['mpg']

# Split to training and test 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# Step 2: Fit Regression Model to Training Set

# %%
# Create object of type linear regression
regr = linear_model.LinearRegression()

# Fit regression model to the training set
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Step 3: Apply Model to the Test Set

# %%
# Apply model to the test set
y_pred_test = regr.predict(x_test)

# %% [markdown]
# Step 4: Evaluate Model Performance on Test Set

# %%
# Comparing true vs predicted values
plt.scatter(y_test, y_pred_test, color='black')
plt.title('Comparing true and predicted values for test set')
plt.xlabel('True values for y')
plt.ylabel('Predicted values for y')

# Model eval
print("Root mean squared error = %.4f" % np.sqrt(mean_squared_error(y_test, y_pred_test)))
print('R-squared = %.4f' % r2_score(y_test, y_pred_test))
# Out:
# Root mean squared error = 4.4749
# R-squared = 0.6511

# %% [markdown]
# Step 5: Postprocessing

# %%
# Display model parameters
print('Slope = ', regr.coef_[0])
print('Intercept = ', regr.intercept_)

# Plot outputs
plt.scatter(x_test, y_test, color='black')
plt.plot(x_test, y_pred_test, color='blue', linewidth=3)
titlestr = 'Predicted Function: y = %.2fX + %.2f' % (regr.coef_[0], regr.intercept_)
plt.title(titlestr)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Slope =  -0.062494306525470986
# Intercept =  35.597521615688834
# Text(0, 0.5, 'y')

# %% [markdown]
# ## Part b: Regression and Classification using a new data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import os
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score


path = "./data/"

filename_read = os.path.join(path, "Admission_Predict_Ver1.1_small_data_set_for_Linear_Regression.csv")
df = pd.read_csv(filename_read, na_values=['NA', '?'])

# Define features (X) and target variable (Y)
X = df[['GRE Score']]
Y = df['Chance of Admit ']


numInstances = 398
numTrain = 100
numTest = numInstances - numTrain

x_train = X[:-numTest]
x_test = X[-numTest:]
y_train = Y[:-numTest]
y_test = Y[-numTest:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Fit regression model to the training set
regr.fit(x_train, y_train)

y_pred_test = regr.predict(x_test)

# Comparing true versus predicted values
plt.scatter(y_test, y_pred_test, color='black')
plt.title('Comparing true and predicted values for test set')
plt.xlabel('True values for y')
plt.ylabel('Predicted values for y')
plt.show()

# Model evaluation
print("Root mean squared error = %.4f" % np.sqrt(mean_squared_error(y_test, y_pred_test)))
print('R-squared = %.4f' % r2_score(y_test, y_pred_test))

# Plot outputs
plt.scatter(x_test, y_test,  color='black')
plt.plot(x_test, y_pred_test, color='blue', linewidth=3)
titlestr = 'Predicted Function: y = %.2fX + %.2f' % (regr.coef_, regr.intercept_)
plt.title(titlestr)
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Root mean squared error = 0.0748
# R-squared = 0.6725
# Text(0, 0.5, 'y')

# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv('data/Admission_Predict_Ver1.1_small_data_set_for_Linear_Regression.csv',header='infer')
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
import os

# Load the dataset
path = "./data/"
filename_read = os.path.join(path, "Admission_Predict_Ver1.1_small_data_set_for_Linear_Regression.csv")
df = pd.read_csv(filename_read, na_values=['NA', '?'])

# Discretize the "Chance of Admission" column into three categories: Low, Medium, High
bins = [0, 0.4, 0.7, 1.0]  # Define the boundaries of the bins
labels = ['Low', 'Medium', 'High']  # Define labels for the bins
df['Admission Category'] = pd.cut(df['Chance of Admit '], bins=bins, labels=labels)

# Drop the original continuous "Chance of Admission" column
df.drop(columns=['Chance of Admit '], inplace=True)

# Prepare the data
X = df.drop(columns=['Admission Category'])  # Features
Y = df['Admission Category']  # Target variable

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# Create a DecisionTreeClassifier object
clf = DecisionTreeClassifier()

# Fit the classifier to the training data
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# Evaluate the performance of the decision tree
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7666666666666667

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))  
plot_tree(clf, filled=True, feature_names=X.columns.tolist(), class_names=clf.classes_.tolist())
plt.show()

# %% [markdown]
# Describe a few rules (3 to 5 valuable rules are sufficient). Which rules do you think are the most valuable?
#
#
# 1. When handling missing values, there are many different approaches that can be taking when constructing a decision tree such as surrogate split method or probabilistic split method. One easy way would be to exclude the instances that contain the missing values.By excluding these instances, these instances won't be counted with the instance related to the node children.
# 2. When it comes to handling interations among attributes, it can be easy to follow when the attributes are together. But when attributes are looked at as individual attributes, it can be difficult because it provides little information. Decisions trees can become more complex when these attributes are not apart of the formation of the tree. Knowing this will help us understand that decision trees can poorly perform when these factors play a role.
# 3. When there are two attributes with the same information gain, this tell us that we are handling redundant attributes. Choose one for splitting.
#
# I think all of of these rules are important to understanding how decision tress work when there is information or data that isn't always concise. Given in real life scenerios, data may need preprocessing and there may be a precense of attributes that are not as useful in assisting the formation of a decision tree.
